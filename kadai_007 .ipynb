# %% [markdown]
# #**★課題「リスト/ディクショナリを使いこなそう」**

# %%
array=["月曜日は晴れです","火曜日は雨です","水曜日は晴れです","木曜日は晴れです",
       "金曜日はくもりです","土曜日は曇りのち雨です","日曜日は雷雨です"]

# %%
print(array) #出力
# Out:
# ['月曜日は晴れです', '火曜日は雨です', '水曜日は晴れです', '木曜日は晴れです', '金曜日はくもりです', '土曜日は曇りのち雨です', '日曜日は雷雨です']

# %%
print(array[2]) #インデックス2を出力
# Out:
# 水曜日は晴れです

# %%
dictionary= {"mon": "晴れ","tue": "雨","wed": "晴れ","thu": "晴れ","fri": "曇り","sat": "曇りのうち雨","sun": "雷雨"}
#キーと配列共に""を付けた、キーの"を消したらエラーでた

# %%
print(dictionary) #出力
# Out:
# {'mon': '晴れ', 'tue': '雨', 'wed': '晴れ', 'thu': '晴れ', 'fri': '曇り', 'sat': '曇りのうち雨', 'sun': '雷雨'}

# %%
print(dictionary["wed"]) #水曜日のキーを[]に入れて出力
# Out:
# 晴れ
